# %%
import camelot as cam
import pandas as pd 
#process_background=True
path="keppel-corporation-limited-annual-report-2018.pdf"

# %%
table = cam.read_pdf(path,pages='69',flavor='stream')
table
# Out:
# <TableList n=2>

# %%
table[1].parsing_report
t=table[1].df

# %%
t=pd.DataFrame(t)
t.to_excel("output.xlsx")

# %%
# import module
from pdf2image import convert_from_path


# Store Pdf with convert_from_path function
images = convert_from_path('/Users/apple/Desktop/thewalnut/A2/keppel-corporation-limited-annual-report-2018.pdf')
images[68].save('page'+ str(68) +'.jpg', 'JPEG')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

file =  "/Users/apple/Desktop/thewalnut/A2/page68.jpg"

im1 = cv2.imread(file, 0)
im = cv2.imread(file)

ret,thresh_value = cv2.threshold(im1,180,255,cv2.THRESH_BINARY_INV)

kernel = np.ones((5,5),np.uint8)
dilated_value = cv2.dilate(thresh_value,kernel,iterations = 1)

contours, hierarchy = cv2.findContours(dilated_value,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cordinates = []
for cnt in contours:
    x,y,w,h = cv2.boundingRect(cnt)
    cordinates.append((x,y,w,h))
    #bounding the images
    if y< 50:
        
        cv2.rectangle(im,(x,y),(x+w,y+h),(0,0,255),1)
        
plt.imshow(im)
cv2.namedWindow('detecttable', cv2.WINDOW_NORMAL)
cv2.imwrite('detecttable.jpg',im)
# Out:
# True
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from tabula import read_pdf
import tabulate
import pandas as pd 

df=read_pdf("keppel-corporation-limited-annual-report-2018.pdf",pages=69,stream=False,output_format='dataframe')

# %%
df[0]
# Out:
#    Board and Committee Meetings and Attendance      Unnamed: 1 Unnamed: 2  \
# 0                                          NaN             NaN        NaN
# 1                                          NaN  Board Meetings      Audit
# 2                                Lee Boon Yang              11          –
# 3                                 Loh Chin Hua              11          –
# 4                                 Tow Heng Tan               8          –
# 5                          Alvin Yeo Khirn Hai               9          5
# 6                                   Tan Ek Kia               9          5
# 7                                   Danny Teoh              10          5
# 8                             Tan Puay Chiang1              10          –
# 9                                Till Vestring              11          –
# 10                                Veronica Eng              11          5
# 11                      Jean-François Manzoni2      3 out of 3          –
# ...
